# %%
import pandas as pd
data=pd.read_csv(r'C:\Users\Manoj-PC\DataScience\Kaggle\house-prices-advanced-regression-techniques\train.csv')

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np

from matplotlib import rcParams
rcParams['figure.figsize'] = 15,4

import seaborn as sb
sb.set_style('whitegrid')

# %%
data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data.Neighborhood.isnull().sum()
# Out:
# 0

# %%
data.loc[:,'Neighborhood'].value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

from matplotlib import rcParams
rcParams['figure.figsize'] = 15,15

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
df_train=pd.read_csv(r'train.csv')
df_test=pd.read_csv(r'test.csv')

# %%
#df_train.head().to_csv('Column_Analysis.csv')

# %%
df_train['Fireplaces'].value_counts()
# Out:
# 0    690
# 1    650
# 2    115
# 3      5
# Name: Fireplaces, dtype: int64

# %%
X=df_train.loc[:,['OverallQual','GrLivArea','YearBuilt','TotalBsmtSF','GarageCars','1stFlrSF','YearRemodAdd','Fireplaces']]
y=df_train.SalePrice

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)

# %%
model.fit(X_train,y_train)
y_predict=model.predict(X_test)

# %%
y_test.head(),y_predict[0:5]
# Out:
# (854    170000
#  381    187750
#  816    137000
#  577    164500
#  35     309000
#  Name: SalePrice, dtype: int64,
#  array([187821.28994796, 214963.40589812, 111274.37601319, 160767.66377121,
#         296139.79402479]))

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import numpy as np
r2_score(y_test,y_predict)
# Out:
# 0.8008373101753037

# %%
X=df_train.loc[:,['OverallQual','GrLivArea','YearBuilt','TotalBsmtSF','GarageCars','1stFlrSF','YearRemodAdd','Fireplaces']]
y=df_train.SalePrice

from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)


from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
y_predict=model.predict(X_test)

print(y_test.head(),y_predict[0:5])
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import numpy as np
print(r2_score(y_test,y_predict))
# Out:
# 854    170000
# 381    187750
# 816    137000
# 577    164500
# 35     309000
# Name: SalePrice, dtype: int64 [187821.28994796 214963.40589812 111274.37601319 160767.66377121
#  296139.79402479]
# 0.8008373101753037

# %% [markdown]
# # Diff Approach

# %%
df_train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sb.distplot(df_train.SalePrice);

# %%
print("Skewness: ", stats.skew(df_train['SalePrice']))
print("Kurtosis: ",stats.kurtosis(df_train['SalePrice']))

print("Skewness: %f" % df_train['SalePrice'].skew())
print("Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
# Skewness:  1.880940746034036
# Kurtosis:  6.509812011089439
# Skewness: 1.882876
# Kurtosis: 6.536282

# %%
sb.scatterplot(x=df_train.GrLivArea,y=df_train.SalePrice);

# %%
sb.scatterplot(x=df_train.TotalBsmtSF,y=df_train.SalePrice);

# %%
sb.boxplot(x=df_train.OverallQual,y=df_train.SalePrice);

# %%
fig=sb.boxplot(x=df_train.YearBuilt,y=df_train.SalePrice);
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);

# %%
#f, ax = plt.subplots(figsize=(12, 9))
sb.heatmap(df_train.corr(),square=False);

# %%
k=10
corrmat=df_train.corr()
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_train[cols].values.T)
hm = sb.heatmap(cm, cbar=True, annot=True, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize = (9, 5)) 
df_train['SalePrice'].plot(kind ="hist");

# %%
corrmat=df_train.corr()
f, ax=plt.subplots(figsize=(10,8))
sb.heatmap(corrmat,ax=ax,cmap="YlGnBu",linewidths=0.1);

# %%
f, ax=plt.subplots(figsize=(8,4))
sb.lineplot(x=df_train.YearBuilt, y=df_train.SalePrice);

# %%
sb.set()
cols=['SalePrice','OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sb.pairplot(df_train[cols], size=2.5)
plt.show();

# %%
total=df_train.isnull().sum().sort_values(ascending=False)
percent=(df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)*100
missing_data=pd.concat([total,percent],axis=1,keys=['Total','Percent'])
missing_data.head(20)
# Out:
#               Total    Percent
# PoolQC         1453  99.520548
# MiscFeature    1406  96.301370
# Alley          1369  93.767123
# Fence          1179  80.753425
# FireplaceQu     690  47.260274
# LotFrontage     259  17.739726
# GarageCond       81   5.547945
# GarageType       81   5.547945
# GarageYrBlt      81   5.547945
# GarageFinish     81   5.547945
# GarageQual       81   5.547945
# BsmtExposure     38   2.602740
# BsmtFinType2     38   2.602740
# BsmtFinType1     37   2.534247
# BsmtCond         37   2.534247
# BsmtQual         37   2.534247
# MasVnrArea        8   0.547945
# MasVnrType        8   0.547945
# Electrical        1   0.068493
# Utilities         0   0.000000

# %%
df_train.corr().MasVnrArea.sort_values()
# Out:
# OverallCond     -0.128101
# EnclosedPorch   -0.110204
# BsmtFinSF2      -0.072319
# LowQualFinSF    -0.069071
# Id              -0.050298
# KitchenAbvGr    -0.037610
# MiscVal         -0.029815
# YrSold          -0.008201
# MoSold          -0.005965
# PoolArea         0.011723
# 3SsnPorch        0.018796
# MSSubClass       0.022936
# BsmtHalfBath     0.026673
# ScreenPorch      0.061466
# BsmtFullBath     0.085310
# BedroomAbvGr     0.102821
# LotArea          0.104160
# BsmtUnfSF        0.114442
# OpenPorchSF      0.125703
# WoodDeckSF       0.159718
# 2ndFlrSF         0.174561
# YearRemodAdd     0.179618
# LotFrontage      0.193458
# HalfBath         0.201444
# Fireplaces       0.249070
# GarageYrBlt      0.252691
# BsmtFinSF1       0.264736
# FullBath         0.276833
# TotRmsAbvGrd     0.280682
# YearBuilt        0.315707
# 1stFlrSF         0.344501
# TotalBsmtSF      0.363936
# GarageCars       0.364204
# GarageArea       0.373066
# GrLivArea        0.390857
# ...

# %%
print(df_train.loc[df_train.FireplaceQu.notnull(),['SalePrice','FireplaceQu']].describe());
print(df_train.loc[df_train.FireplaceQu.notnull(),['SalePrice','FireplaceQu']].head(10));
print(df_train.FireplaceQu.value_counts())
# Out:
#            SalePrice
# count     770.000000
# mean   216397.692208
# std     86843.901262
# min     60000.000000
# 25%    159000.000000
# 50%    191000.000000
# 75%    257375.000000
# max    755000.000000
#     SalePrice FireplaceQu
# 1      181500          TA
# 2      223500          TA
# 3      140000          Gd
# 4      250000          TA
# 6      307000          Gd
# 7      200000          TA
# 8      129900          TA
# 9      118000          TA
# 11     345000          Gd
# 13     279500          Gd
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
f, ax=plt.subplots(figsize=(8,4))
sb.scatterplot(x=df_train.FireplaceQu.notnull(),y=df_train.SalePrice);

# %%
df_train.isna().Electrical.sum()
# Out:
# 1

# %%
df_train.loc[:,'Electrical'].value_counts()
# Out:
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
df_train.dropna(thresh=2).shape
# Out:
# (1460, 81)

# %%
df_train = df_train.drop((missing_data[missing_data['Total'] > 1]).index,1)
df_train = df_train.drop(df_train.loc[df_train['Electrical'].isnull()].index)
df_train.isnull().sum().max()
# Out:
# 0

# %%
df_train.shape
# Out:
# (1459, 63)

# %%
saleprice_scaled = StandardScaler().fit_transform(df_train['SalePrice'][:,np.newaxis]);
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print('outer range (low) of the distribution:')
print(low_range)
print('\nouter range (high) of the distribution:')
print(high_range)
# Out:
# outer range (low) of the distribution:
# [[-1.83820775]
#  [-1.83303414]
#  [-1.80044422]
#  [-1.78282123]
#  [-1.77400974]
#  [-1.62295562]
#  [-1.6166617 ]
#  [-1.58519209]
#  [-1.58519209]
#  [-1.57269236]]
#
# outer range (high) of the distribution:
# [[3.82758058]
#  [4.0395221 ]
#  [4.49473628]
#  [4.70872962]
#  [4.728631  ]
#  [5.06034585]
#  [5.42191907]
#  [5.58987866]
#  [7.10041987]
#  [7.22629831]]

# %%
var = 'GrLivArea'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#deleting points
df_train.sort_values(by = 'GrLivArea', ascending = False)[:2]
df_train = df_train.drop(df_train[df_train['Id'] == 1299].index)
df_train = df_train.drop(df_train[df_train['Id'] == 524].index)

# %%
#bivariate analysis saleprice/grlivarea
var = 'TotalBsmtSF'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#histogram and normal probability plot
sb.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)

# %%
df_train['SalePrice'] = np.log(df_train['SalePrice'])

# %%
sb.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['SalePrice'], plot=plt)

# %%
sb.distplot(df_train['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['GrLivArea'], plot=plt)

# %%
df_train['GrLivArea'] = np.log(df_train['GrLivArea'])

# %%
sb.distplot(df_train['GrLivArea'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['GrLivArea'], plot=plt)

# %%
#histogram and normal probability plot
sb.distplot(df_train['TotalBsmtSF'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train['TotalBsmtSF'], plot=plt)

# %%
#create column for new variable (one is enough because it's a binary categorical feature)
#if area>0 it gets 1, for area==0 it gets 0
df_train['HasBsmt'] = pd.Series(len(df_train['TotalBsmtSF']), index=df_train.index)
df_train['HasBsmt'] = 0 
df_train.loc[df_train['TotalBsmtSF']>0,'HasBsmt'] = 1

# %%
df_train.loc[df_train['HasBsmt']==1,'TotalBsmtSF'] = np.log(df_train['TotalBsmtSF'])

# %%
#histogram and normal probability plot
sb.distplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], fit=norm);
fig = plt.figure()
res = stats.probplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], plot=plt)

# %%
#scatter plot
plt.scatter(df_train['GrLivArea'], df_train['SalePrice']);

# %%
#scatter plot
plt.scatter(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], df_train[df_train['TotalBsmtSF']>0]['SalePrice']);

# %%
#convert categorical variable into dummy
df_train = pd.get_dummies(df_train)
df_train.dropna(inplace=True)

# %%
#X=df_train.loc[:,['OverallQual','GrLivArea','YearBuilt','TotalBsmtSF','GarageCars','1stFlrSF','YearRemodAdd','Fireplaces']]
X=df_train.loc[:,['OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']]
y=df_train.SalePrice

from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=10)


from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
y_predict=model.predict(X_test)

print(y_test.head(),y_predict[0:5])
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import numpy as np
print(r2_score(y_test,y_predict))
# Out:
# 1388    12.841326
# 1431    11.875831
# 720     12.524526
# 577     12.010666
# 35      12.641097
# Name: SalePrice, dtype: float64 [12.6286941  11.84039032 12.38974628 11.88913422 12.65090277]
# 0.8182719074486802

# %%
from xgboost import XGBRegressor
model=XGBRegressor(n_estimators=400,
              learning_rate=0.1,
              subsample=1,
             # colsample_bylevel=0.5,
             # colsample_bytree=0.7,
              max_depth=10,
              min_child_weight=1 , #1,10,50 ...... affects accuracy highlly
              reg_alpha=0,
              reg_lambda=1,
              gamma=0, #increasing leads to overfitting
             )

# %%
model.fit(X_train,y_train)
y_predict=model.predict(X_test)

print(y_test.head(),y_predict[0:5])
from sklearn.metrics import r2_score
import numpy as np
print(r2_score(y_test,y_predict))
y_predict[0:5]
# Out:
# [23:40:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 1388    12.841326
# 1431    11.875831
# 720     12.524526
# 577     12.010666
# 35      12.641097
# Name: SalePrice, dtype: float64 [12.700043 11.895984 12.44     11.799664 12.740339]
# 0.8025968240630037
# array([12.700043, 11.895984, 12.44    , 11.799664, 12.740339],
#       dtype=float32)

# %%
y_actual = np.exp(y_predict) 

print(np.exp(y_predict[0:5]))
print(np.exp(df_train['SalePrice']).head())
# Out:
# [327761.9  146676.34 252710.44 133207.53 341239.3 ]
# 0    208500.0
# 1    181500.0
# 2    223500.0
# 3    140000.0
# 4    250000.0
# Name: SalePrice, dtype: float64
